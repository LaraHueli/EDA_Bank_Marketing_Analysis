# %%
# Importaciones 
import pandas as pd
import numpy as np
import sys

# Añadir la ruta al directorio 'src'
sys.path.append(r'C:\Users\antonio\Desktop\EDA_Bank_Marketing_Analysis\src')

# Importar las funciones del archivo 'sp_limpieza.py' en 'src'
from sp_limpieza import eda_preliminar, valores_minuscula, reemplazar_nulos, unificar_categorias, eliminar_columnas

# %%
# leemos el archivo 
df= pd.read_csv('C:/Users/antonio/Desktop/EDA_Bank_Marketing_Analysis/Data/data_transformacion/bank-transformed.csv')

# %%
eda_preliminar(df)

# %%
valores_minuscula(df)

# %%
df = reemplazar_nulos(df, 'education', 'sin especificar')
df = unificar_categorias(df, 'education', ['basic.4y', 'basic.6y', 'basic.9y'], 'basic')
df = eliminar_columnas(df, ['latitude', 'longitude'])

# %%
# Reemplazar los valores nulos en 'age' por 0
df['age'] = df['age'].fillna(0).astype(int)

# %%
# Unificar las categorías básicas
df['education'] = df['education'].replace(['basic.4y', 'basic.6y', 'basic.9y'], 'basic')
# Reemplazar los valores nulos por 'sin especificar'
df['education'] = df['education'].fillna('sin especificar')

# %%
eda_preliminar(df)
# Out:
#        age          job  marital            education  default  housing  loan  \
# 6199    38       admin.  married    university.degree      0.0      0.0   0.0
# 261     55  blue-collar  married                basic      NaN      0.0   0.0
# 35358   34       admin.   single    university.degree      0.0      0.0   0.0
# 30588   50  blue-collar  married                basic      0.0      1.0   0.0
# 2607    34   technician   single  professional.course      0.0      0.0   0.0
#
#          contact  duration  campaign  ...  previous     poutcome emp.var.rate  \
# 6199   telephone       141         3  ...         0  nonexistent          1.1
# 261    telephone       102         2  ...         0  nonexistent          1.1
# 35358   cellular       283         1  ...         0  nonexistent         -1.8
# 30588   cellular       392         1  ...         0  nonexistent         -1.8
# 2607   telephone        27         1  ...         0  nonexistent          1.1
#
# ...

# %%
df.sample(20)
# Out:
#        age            job   marital          education  default  housing  \
# 22705   57    blue-collar   married              basic      0.0      1.0
# 8168    43    blue-collar   married              basic      0.0      0.0
# 11861   39         admin.    single        high.school      0.0      0.0
# 23011    0     management   married  university.degree      0.0      0.0
# 3355    35  self-employed   married  university.degree      NaN      1.0
# 40767   27         admin.    single  university.degree      0.0      0.0
# 26528   30     unemployed   married  university.degree      0.0      0.0
# 7334    37    blue-collar    single    sin especificar      NaN      0.0
# 42573   26     unemployed   married        high.school      0.0      1.0
# 8204    53         admin.   married        high.school      0.0      0.0
# 24304    0    blue-collar   married              basic      NaN      1.0
# 22525   60     management   married  university.degree      0.0      1.0
# ...
