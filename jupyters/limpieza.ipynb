# %%
# Importaciones 
import pandas as pd
import numpy as np
import locale # configuraciones regionales
import os
 
# Establecer el locale a español
locale.setlocale(locale.LC_TIME, 'es_ES.UTF-8')

import sys
sys.path.append('C:/Users/antonio/Desktop/EDA_Bank_Marketing_Analysis/src')  # Sustituye por la ruta absoluta de tu proyecto


# Importar las funciones del archivo 'sp_limpieza.py' en 'src'
from sp_limpieza import eda_preliminar
from sp_limpieza import valores_minuscula
from sp_limpieza import reemplazar_nulos 
from sp_limpieza import unificar_categorias
from sp_limpieza import eliminar_columnas
from sp_limpieza import unificar_education
from sp_limpieza import convertir_float_a_int
from sp_limpieza import limpiar_columnas
from sp_limpieza import convertir_int_a_float
from sp_limpieza import convertir_fecha

# %%
# leemos el archivo 
df= pd.read_csv('C:/Users/antonio/Desktop/EDA_Bank_Marketing_Analysis/Data/data_transformacion/bank-transformed.csv')

# %%
# primer vistazo
eda_preliminar(df)
# Out:
#        age          job  marital          education  default  housing  loan  \
# 7634   NaN     services   SINGLE           basic.9y      0.0      0.0   0.0
# 7950  41.0  blue-collar  MARRIED           basic.9y      0.0      0.0   0.0
# 9565  44.0       admin.  MARRIED  university.degree      NaN      0.0   0.0
# 8125  34.0  blue-collar  MARRIED           basic.4y      0.0      0.0   0.0
# 5415  35.0     services  MARRIED        high.school      0.0      1.0   0.0
#
#         contact  duration  campaign  ...  emp.var.rate  cons.price.idx  \
# 7634  telephone      1044         5  ...           1.1          93,994
# 7950  telephone       345         3  ...           1.4          94,465
# 9565  telephone        78         3  ...           1.4          94,465
# 8125  telephone       404        13  ...           1.4          94,465
# 5415  telephone       368         6  ...           1.1          93,994
#
#      cons.conf.idx  euribor3m nr.employed    y               date latitude  \
# 7634         -36,4      4,864        5191  yes      11-marzo-2015   30.322
# 7950         -41,8      4,865      5228,1   no      21-abril-2017   43.873
# 9565         -41,8      4,961      5228,1   no       12-mayo-2018   43.729
# 8125         -41,8      4,864      5228,1   no       3-julio-2017   27.156
# 5415         -36,4      4,857        5191   no  24-diciembre-2018   35.314
#
#      longitude                                   id_
# 7634   -71.018  0401a733-7aa5-4f58-87de-a13304642b61
# 7950  -117.872  726f1b4d-3366-4aae-87ce-ffd13a9bca02
# 9565   -70.456  a8dab5fb-492c-42a3-8f68-b5079cabccee
# 8125   -86.784  ce182625-53ef-4e0a-8669-8cae4c213784
# 5415   -83.251  3aae8934-e1c7-4868-844f-ddfbd12e81c4
#
# [5 rows x 23 columns]
# --------------------------------------------------------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             37880 non-null  float64
#  1   job             42655 non-null  object
#  2   marital         42915 non-null  object
#  3   education       41193 non-null  object
#  4   default         34019 non-null  float64
#  5   housing         41974 non-null  float64
#  6   loan            41974 non-null  float64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp.var.rate    43000 non-null  float64
#  14  cons.price.idx  42529 non-null  object
#  15  cons.conf.idx   43000 non-null  object
#  16  euribor3m       33744 non-null  object
#  17  nr.employed     43000 non-null  object
#  18  y               43000 non-null  object
#  19  date            42752 non-null  object
#  20  latitude        43000 non-null  float64
#  21  longitude       43000 non-null  float64
#  22  id_             43000 non-null  object
# dtypes: float64(7), int64(4), object(12)
# memory usage: 7.5+ MB
# None
# --------------------------------------------------------------
# NULOS
# age               11.91
# job                0.80
# marital            0.20
# education          4.20
# default           20.89
# housing            2.39
# loan               2.39
# contact            0.00
# duration           0.00
# campaign           0.00
# pdays              0.00
# previous           0.00
# poutcome           0.00
# emp.var.rate       0.00
# cons.price.idx     1.10
# cons.conf.idx      0.00
# euribor3m         21.53
# nr.employed        0.00
# y                  0.00
# date               0.58
# latitude           0.00
# longitude          0.00
# id_                0.00
# dtype: float64
# --------------------------------------------------------------
# DUPLICADOS
# np.int64(0)
# --------------------------------------------------------------
# CATEGORIAS
# Index(['job', 'marital', 'education', 'contact', 'poutcome', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'date', 'id_'],
#       dtype='object')
# --------------------------------------------------------------
# VALUE COUNTS
# job
# admin.           10873
# blue-collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self-employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# Name: count, dtype: int64
# --------------------------------------------------------------
# marital
# MARRIED     25999
# SINGLE      12105
# DIVORCED     4811
# Name: count, dtype: int64
# --------------------------------------------------------------
# education
# university.degree      12722
# high.school             9925
# basic.9y                6309
# professional.course     5477
# basic.4y                4356
# basic.6y                2386
# illiterate                18
# Name: count, dtype: int64
# --------------------------------------------------------------
# contact
# cellular     27396
# telephone    15604
# Name: count, dtype: int64
# --------------------------------------------------------------
# poutcome
# NONEXISTENT    37103
# FAILURE         4461
# SUCCESS         1436
# Name: count, dtype: int64
# --------------------------------------------------------------
# cons.price.idx
# 93,994    7938
# 93,918    6937
# 92,893    5985
# 93,444    5349
# 94,465    4522
# 93,2      3731
# 93,075    2552
# 92,201     803
# 92,963     742
# 92,431     471
# 92,649     375
# 94,215     320
# 94,199     316
# 92,843     298
# 92,379     274
# 93,369     271
# 94,027     242
# 94,055     236
# 93,876     224
# 94,601     212
# 92,469     184
# 92,713     179
# 93,749     179
# 94,767     130
# 93,798      48
# 92,756      11
# Name: count, dtype: int64
# --------------------------------------------------------------
# cons.conf.idx
# -36,4    8020
# -42,7    7004
# -46,2    6057
# -36,1    5408
# -41,8    4568
# -42      3782
# -47,1    2581
# -31,4     815
# -40,8     748
# -26,9     477
# -30,1     379
# -40,3     328
# -37,5     318
# -50       299
# -29,8     277
# -34,8     275
# -38,3     245
# -39,8     239
# -40       225
# -49,5     214
# -33,6     185
# -34,6     183
# -33       181
# -50,8     133
# -40,4      48
# -45,9      11
# Name: count, dtype: int64
# --------------------------------------------------------------
# euribor3m
# 4,857    2287
# 4,962    2124
# 4,963    2019
# 4,961    1594
# 4,964     964
#          ...
# 3,743       1
# 3,563       1
# 3,488       1
# 3,428       1
# 0,969       1
# Name: count, Length: 309, dtype: int64
# --------------------------------------------------------------
# nr.employed
# 5228,1    16980
# 5099,1     8937
# 5191       8020
# 5195,8     3830
# 5076,2     1748
# 5017,5     1133
# 4991,6      812
# 5008,7      683
# 4963,6      665
# 5023,5      181
# 5176,3       11
# Name: count, dtype: int64
# --------------------------------------------------------------
# y
# no     38156
# yes     4844
# Name: count, dtype: int64
# --------------------------------------------------------------
# date
# 28-febrero-2018      95
# 28-febrero-2016      94
# 28-febrero-2015      92
# 28-febrero-2017      89
# 28-febrero-2019      85
#                      ..
# 2-julio-2016         11
# 14-abril-2015        10
# 20-noviembre-2015    10
# 4-abril-2017         10
# 21-diciembre-2019    10
# Name: count, Length: 1825, dtype: int64
# --------------------------------------------------------------
# id_
# 089b39d8-e4d0-461b-87d4-814d71e0e079    1
# c25b5d31-bb7e-41af-898d-42bf3e479351    1
# bfd6bad9-f23a-445a-838e-10ee90110534    1
# 075b0e72-b5e3-43f4-90cd-29f9090b2b1a    1
# 482a2d86-c9f0-46b7-9f6f-82c769690d48    1
#                                        ..
# 27e317a2-722c-454d-850b-97b536029c81    1
# 6d9c117f-af67-4a89-83db-caf514a42374    1
# 6a229b87-6bf9-4339-9639-b98555df71e7    1
# cc891cf7-206c-47f0-804f-20b5b757d5fc    1
# 993bbbd6-4dbc-4a40-a408-f91f8462bee6    1
# Name: count, Length: 43000, dtype: int64
# --------------------------------------------------------------

# %%
# llamadas a funciones del src (trasnformacion y limieza)
df = valores_minuscula(df)
df = unificar_education(df) 
df = unificar_categorias(df, 'education', ['basic.4y', 'basic.6y', 'basic.9y'], 'basic')
df = eliminar_columnas(df, ['latitude', 'longitude'])
df = convertir_float_a_int(df, ['age','housing', 'loan'])
df = convertir_int_a_float (df, 'nr.employed')
df = convertir_fecha (df, 'date')
df = df.drop(columns=['date'])

# %%
# Limpiar y convertir las columnas a float
df['cons.price.idx'] = df['cons.price.idx'].str.replace(',', '').astype(float)
df['cons.conf.idx'] = df['cons.conf.idx'].str.replace(',', '').astype(float)

# %%
eda_preliminar(df)
# Out:
#        age          job  marital            education  default  housing  loan  \
# 3666    43  blue-collar  married                basic      NaN        0     0
# 12701   26  blue-collar  married                basic      NaN        0     0
# 4401    34  blue-collar  married                basic      0.0        0     1
# 307     42   technician   single  professional.course      NaN        1     0
# 36742   50       admin.  married    university.degree      0.0        0     0
#
#          contact  duration  campaign  ...  emp.var.rate  cons.price.idx  \
# 3666   telephone       217         1  ...           1.1         93994.0
# 12701   cellular        99         1  ...           1.4         93918.0
# 4401   telephone       289         3  ...           1.1         93994.0
# 307    telephone       152         2  ...           1.1         93994.0
# 36742   cellular       269         1  ...          -2.9         92963.0
#
#       cons.conf.idx  euribor3m  nr.employed    y  \
# 3666         -364.0        NaN       5191.0   no
# 12701        -427.0      4,962       5228.1   no
# 4401         -364.0      4,856       5191.0   no
# 307          -364.0      4,857       5191.0   no
# 36742        -408.0        NaN       5076.2  yes
#
#                                         id_  year month day
# 3666   61bbeae1-ecef-40f9-bf85-671a20c0066d  2015    11  13
# 12701  99bea9d7-bfd0-41cd-8cb4-360d8b24fc44  2019    10  20
# 4401   a6cf827c-49de-4bef-b7a9-97bc0e42fc3d  2017    12   7
# 307    9408bce6-81c6-465a-9db0-37af3525638a  2015     1  23
# 36742  d25f959d-3d83-4760-870f-712022b21352  2019     6  13
#
# [5 rows x 23 columns]
# --------------------------------------------------------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             43000 non-null  int64
#  1   job             42655 non-null  object
#  2   marital         42915 non-null  object
#  3   education       43000 non-null  object
#  4   default         34019 non-null  float64
#  5   housing         43000 non-null  int64
#  6   loan            43000 non-null  int64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp.var.rate    43000 non-null  float64
#  14  cons.price.idx  42529 non-null  float64
#  15  cons.conf.idx   43000 non-null  float64
#  16  euribor3m       33744 non-null  object
#  17  nr.employed     43000 non-null  float64
#  18  y               43000 non-null  object
#  19  id_             43000 non-null  object
#  20  year            43000 non-null  int64
#  21  month           43000 non-null  int64
#  22  day             43000 non-null  int64
# dtypes: float64(5), int64(10), object(8)
# memory usage: 7.5+ MB
# None
# --------------------------------------------------------------
# NULOS
# age                0.00
# job                0.80
# marital            0.20
# education          0.00
# default           20.89
# housing            0.00
# loan               0.00
# contact            0.00
# duration           0.00
# campaign           0.00
# pdays              0.00
# previous           0.00
# poutcome           0.00
# emp.var.rate       0.00
# cons.price.idx     1.10
# cons.conf.idx      0.00
# euribor3m         21.53
# nr.employed        0.00
# y                  0.00
# id_                0.00
# year               0.00
# month              0.00
# day                0.00
# dtype: float64
# --------------------------------------------------------------
# DUPLICADOS
# np.int64(0)
# --------------------------------------------------------------
# CATEGORIAS
# Index(['job', 'marital', 'education', 'contact', 'poutcome', 'euribor3m', 'y',
#        'id_'],
#       dtype='object')
# --------------------------------------------------------------
# VALUE COUNTS
# job
# admin.           10873
# blue-collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self-employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# Name: count, dtype: int64
# --------------------------------------------------------------
# marital
# married     25999
# single      12105
# divorced     4811
# Name: count, dtype: int64
# --------------------------------------------------------------
# education
# basic                  13051
# university.degree      12722
# high.school             9925
# professional.course     5477
# sin especificar         1807
# illiterate                18
# Name: count, dtype: int64
# --------------------------------------------------------------
# contact
# cellular     27396
# telephone    15604
# Name: count, dtype: int64
# --------------------------------------------------------------
# poutcome
# nonexistent    37103
# failure         4461
# success         1436
# Name: count, dtype: int64
# --------------------------------------------------------------
# euribor3m
# 4,857    2287
# 4,962    2124
# 4,963    2019
# 4,961    1594
# 4,964     964
#          ...
# 3,743       1
# 3,563       1
# 3,488       1
# 3,428       1
# 0,969       1
# Name: count, Length: 309, dtype: int64
# --------------------------------------------------------------
# y
# no     38156
# yes     4844
# Name: count, dtype: int64
# --------------------------------------------------------------
# id_
# 089b39d8-e4d0-461b-87d4-814d71e0e079    1
# c25b5d31-bb7e-41af-898d-42bf3e479351    1
# bfd6bad9-f23a-445a-838e-10ee90110534    1
# 075b0e72-b5e3-43f4-90cd-29f9090b2b1a    1
# 482a2d86-c9f0-46b7-9f6f-82c769690d48    1
#                                        ..
# 27e317a2-722c-454d-850b-97b536029c81    1
# 6d9c117f-af67-4a89-83db-caf514a42374    1
# 6a229b87-6bf9-4339-9639-b98555df71e7    1
# cc891cf7-206c-47f0-804f-20b5b757d5fc    1
# 993bbbd6-4dbc-4a40-a408-f91f8462bee6    1
# Name: count, Length: 43000, dtype: int64
# --------------------------------------------------------------

# %%
df.sample(4)
# Out:
#        age          job  marital    education  default  housing  loan  \
# 16049   49  blue-collar  married        basic      NaN        0     0
# 40937   46       admin.   single  high.school      0.0        1     0
# 42485   27  blue-collar  married        basic      NaN        0     0
# 305     46     services  married  high.school      NaN        1     0
#
#          contact  duration  campaign  ...  emp.var.rate  cons.price.idx  \
# 16049   cellular       270         2  ...           1.4         93918.0
# 40937   cellular       199         2  ...          -1.1         94767.0
# 42485   cellular       877         7  ...          -1.8         92893.0
# 305    telephone       313         3  ...           1.1         93994.0
#
#       cons.conf.idx  euribor3m  nr.employed    y  \
# 16049        -427.0      4,961       5228.1   no
# 40937        -508.0      1,048       4963.6   no
# 42485        -462.0      1,299       5099.1  yes
# 305          -364.0      4,857       5191.0   no
#
#                                         id_  year month day
# 16049  7a75ee98-1b6d-4284-82ea-404801c8039a  2017     7  31
# 40937  15eb05b9-5b3e-4c7a-873e-1d722654f57c  2018    12  13
# 42485  19ab0d3a-f640-4f50-a258-ef07f9ed97d3  2019    10  16
# 305    e6e18c6f-24ce-4ef8-b5dd-4011b94d78ef  2019     3  21
#
# [4 rows x 23 columns]

# %%
# Definir la rutaruta = 'data'
ruta = 'data'

# Crear el directorio si no existe
if not os.path.exists(ruta):
    os.makedirs(ruta)

# Guardar el archivo
df.to_csv(f'{ruta}/bank-cleaned.csv', index=False)

# %%
df_cleaned = pd.read_csv('../data/data_transformacion/bank-cleaned.csv')
display(df_cleaned.head())  # Ver las primeras filas
print(df_cleaned.info())  # Ver estructura y tipos de datos
# Out:
#    age        job  marital    education  default  housing  loan    contact  \
# 0    0  housemaid  married        basic      0.0        0     0  telephone
# 1   57   services  married  high.school      NaN        0     0  telephone
# 2   37   services  married  high.school      0.0        1     0  telephone
# 3   40     admin.  married        basic      0.0        0     0  telephone
# 4   56   services  married  high.school      0.0        0     1  telephone
#
#    duration  campaign  ...  emp.var.rate  cons.price.idx cons.conf.idx  \
# 0       261         1  ...           1.1         93994.0        -364.0
# 1       149         1  ...           1.1         93994.0        -364.0
# 2       226         1  ...           1.1         93994.0        -364.0
# 3       151         1  ...           1.1         93994.0        -364.0
# 4       307         1  ...           1.1         93994.0        -364.0
#
#    euribor3m  nr.employed   y                                   id_  year  \
# 0      4,857       5191.0  no  089b39d8-e4d0-461b-87d4-814d71e0e079  2019
# 1        NaN       5191.0  no  e9d37224-cb6f-4942-98d7-46672963d097  2016
# 2      4,857       5191.0  no  3f9f49b5-e410-4948-bf6e-f9244f04918b  2019
# 3        NaN       5191.0  no  9991fafb-4447-451a-8be2-b0df6098d13e  2015
# 4        NaN       5191.0  no  eca60b76-70b6-4077-80ba-bc52e8ebb0eb  2017
#
#   month day
# 0     8   2
# 1     9  14
# 2     2  15
# 3    11  29
# 4     1  29
#
# [5 rows x 23 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             43000 non-null  int64
#  1   job             42655 non-null  object
#  2   marital         42915 non-null  object
#  3   education       43000 non-null  object
#  4   default         34019 non-null  float64
#  5   housing         43000 non-null  int64
#  6   loan            43000 non-null  int64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp.var.rate    43000 non-null  float64
#  14  cons.price.idx  42529 non-null  float64
#  15  cons.conf.idx   43000 non-null  float64
#  16  euribor3m       33744 non-null  object
#  17  nr.employed     43000 non-null  float64
#  18  y               43000 non-null  object
#  19  id_             43000 non-null  object
#  20  year            43000 non-null  int64
#  21  month           43000 non-null  int64
#  22  day             43000 non-null  int64
# dtypes: float64(5), int64(10), object(8)
# memory usage: 7.5+ MB
# None
